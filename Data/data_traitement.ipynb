# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("Base_Familia_FINAL_com_GPS_fr.xlsx")

# %%
Print("97.61% de personnes qui déclarent avoir ne activité agricole")

# %%
data['Q_3.4.2_emploi_agricole'].value_counts()
# Out:
# 0    538
# 1      5
#        1
# Name: Q_3.4.2_emploi_agricole, dtype: int64

# %%
data['Q_3.4.2_activites_agricoles'].value_counts()
# Out:
# 1    531
# 0     12
#        1
# Name: Q_3.4.2_activites_agricoles, dtype: int64

# %%
activite_agricole = data.loc[data['Q_3.4.2_activites_agricoles'] == 1]
activite_agricole
# Out:
#      Identifiant    Q_2.2_municipe              Q_2.2.1_zone Q_3.1.3_genre  \
# 0              1          Santarem                 S1 Cipoal         Femme
# 1              2          Santarem       S3 Fin de Curuá Una         Homme
# 4              5          Santarem     S2 Debut de Curuá Una         Femme
# 5              6          Santarem     S2 Debut de Curuá Una         Femme
# 6              7          Santarem     S2 Debut de Curuá Una         Homme
# ..           ...               ...                       ...           ...
# 539          540          Belterra              B4 St George         Homme
# 540          541          Belterra              B4 St George         Homme
# 541          542          Belterra              B4 St George         Homme
# 542          543          Santarem                 S4 Ituqui         Femme
# 543          544  Mojuí dos Campos  M5 Bonne chance (farine)         Homme
#
#                     Q_3.1.4_Scolarite  \
# ...

# %%
plt.hist(activite_agricole['Q_3.4.2_etude'])
# Out:
# (array([507.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,  24.]),
#  array([0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.6000000000000001,
#         0.7000000000000001, 0.8, 0.9, 1.0], dtype=object),
#  <BarContainer object of 10 artists>)

# %%
premiere_colonne = data[data.columns[]]
premiere_colonne
# Out:
# 0              Santarem
# 1              Santarem
# 2              Santarem
# 3              Santarem
# 4              Santarem
#              ...
# 539            Belterra
# 540            Belterra
# 541            Belterra
# 542            Santarem
# 543    Mojuí dos Campos
# Name: Q_2.2_municipe, Length: 544, dtype: object

# %%
tets = pd.get_dummies(data)
tets.to_csv('tropcool1.csv')
